# %%
import numpy as np
from collections import Counter
import math

def hex_to_bytes(hex_str):
    """Convert hexadecimal string to bytes."""
    return bytes.fromhex(hex_str)

def calculate_entropy(data):
    """Calculate the entropy of a given data."""
    if not data:
        return 0
    entropy = 0
    data_len = len(data)
    counter = Counter(data)
    for count in counter.values():
        probability = count / data_len
        entropy -= probability * math.log2(probability)
    return entropy

def top_n_frequencies(data, n=5):
    """Calculate the top-N frequencies of characters in the data."""
    freq_dist = Counter(data)
    most_common = freq_dist.most_common(n)
    return {f'top_{i+1}_freq': count for i, (char, count) in enumerate(most_common)}

def extract_features(ciphertext_hex, features):
    """Extract features from the given ciphertext in hexadecimal form."""
    # Convert hex to bytes
    ciphertext_bytes = hex_to_bytes(ciphertext_hex)

    # Ciphertext length
    features['length'] = len(ciphertext_bytes)

    # Entropy
    features['entropy'] = calculate_entropy(ciphertext_bytes)

    # Frequency distribution
    freq_dist = top_n_frequencies(ciphertext_bytes)
    features.update({f'freq_{byte}': count for byte, count in freq_dist.items()})

    # Block size (assuming common block sizes)
    block_sizes = [8, 16, 32]
    for block_size in block_sizes:
        if len(ciphertext_bytes) % block_size == 0:
            features['block_size'] = block_size
            break
    else:
        features['block_size'] = None

    # Feature 3: Byte Distribution
    byte_distribution = Counter(ciphertext_bytes)
    features['byte_distribution_mean'] = np.mean(list(byte_distribution.values()))
    features['byte_distribution_std'] = np.std(list(byte_distribution.values()))

    # Feature 4: Repetition Patterns
    repetition_count = sum([ciphertext_bytes[i] == ciphertext_bytes[i+1] for i in range(len(ciphertext_bytes) - 1)])
    features['repetition_count'] = repetition_count / len(ciphertext_bytes)

    # Feature 5: Hamming Distance Between Adjacent Blocks
    block_size = features['block_size']  # Assuming AES-like block size
    if (features['block_size'] == None):
        hamming_distances = []
    else:
        hamming_distances = []
        for i in range(0, len(ciphertext_bytes) - block_size, block_size):
            block1 = ciphertext_bytes[i:i+block_size]
            block2 = ciphertext_bytes[i+block_size:i+2*block_size]
            hamming_distances.append(np.sum(np.bitwise_xor(list(block1), np.array(list(block2)))))
    features['avg_hamming_distance'] = np.mean(hamming_distances) if hamming_distances else 0

    # Feature 7: Bit-Level Features
    bits = ''.join(format(byte, '08b') for byte in ciphertext_bytes)
    features['bit_zeros_ratio'] = bits.count('0') / len(bits)
    features['bit_ones_ratio'] = bits.count('1') / len(bits)

    # Feature 8: Padding Detection
    padding_byte = ciphertext_bytes[-1]
    padding_length = padding_byte if all(byte == padding_byte for byte in ciphertext_bytes[-padding_byte:]) else 0
    features['padding_length'] = padding_length

    return features

def extract_iv_and_infer_mode(ciphertext_hex, features, block_size=16):
    """Extract IV and infer mode of operation from the given ciphertext in hexadecimal form."""
    # Convert hex to bytes
    ciphertext_bytes = hex_to_bytes(ciphertext_hex)

    # Extract IV (assuming it's the first block)
    iv = ciphertext_bytes[:block_size]
    features['iv'] = iv

    # Infer mode of operation (basic heuristics)
    if len(ciphertext_bytes) % block_size != 0:
        features['mode'] = 'Unknown or Stream Cipher'
    else:
        # Check for ECB patterns (repeated blocks)
        blocks = [ciphertext_bytes[i:i+block_size] for i in range(0, len(ciphertext_bytes), block_size)]
        if len(blocks) != len(set(blocks)):
            features['mode'] = 'ECB'
        else:
            features['mode'] = 'CBC or other block mode'

    return features

def save_features_to_excel(features, filename='features.xlsx'):
    """Convert features dictionary to DataFrame and save as Excel file."""
    # Convert dictionary to DataFrame
    df = pd.DataFrame([features])

    # Save DataFrame to Excel file
    df.to_excel(filename, index=False)
    print(f"Features saved to {filename}")

# %%
import pandas as pd
df = pd.DataFrame(pd.read_excel('Final_Testing_New.xlsx'))
df.head()
# Out:
#                                        Original Text  Length  \
# 0  cloud computing presents certain challenges, s...     136
# 1  Cooper decides to use the black hole itself,\n...     143
# 2  solution for organizations with common goals w...     132
# 3  g in their home.\n \n Books fall from shelves,...     144
# 4  r high availability, downtime and service inte...     151
#
#                              Encrypted Data (Binary)  \
# 0  b'\x85\x1a\x83\xd1\x8b\xe5\xb5\xba\x06\x8e\xe1...
# 1  b"\xf5l\xc5\x96\x8d\t\xca\x19i\x94S\x08\xa8\x9...
# 2  b"JtY\xbbx\x90V\xfe\xc5\xe0g\xe8&g\x89\xe2\xdb...
# 3  b'\xe3\xbe\xf5\x95\xd2\xce\x0f\xa3"j\x9e-\xa9\...
# 4  b"\xad2\x80-\xdb\xe9m$\xf9n\xf0\x9f|\xb2\xc5A\...
#
#                                 Encrypted Data (Hex) Algorithm
# 0  851a83d18be5b5ba068ee1609d8f87ef7519a36db67282...       AES
# 1  f56cc5968d09ca1969945308a89f660462a5d59feb0bbb...       ECC
# 2  4a7459bb789056fec5e067e8266789e2db9620723b70aa...       AES
# 3  e3bef595d2ce0fa3226a9e2da9bd486a359a1670c93296...       ECC
# 4  ad32802ddbe96d24f96ef09f7cb2c541dec00a34541b1e...       AES

# %%
features_dataset = []

for i in range(0, len(df)):
    features = {}
    features['Original Text'] = df['Original Text'][i]
    features['Length'] = df['Length'][i]
    features['Encrypted Data (Binary)'] = df['Encrypted Data (Binary)'][i]
    features['Encrypted Data (Hex)'] = df['Encrypted Data (Hex)'][i]
    features['Algorithm'] = df['Algorithm'][i]
    j = df['Encrypted Data (Hex)'][i]
    features = extract_features(j, features=features)
    features = extract_iv_and_infer_mode(j, features=features)
    print(features)
    features_dataset.append(features)
# Out:
# {'Original Text': 'cloud computing presents certain challenges, such as security and compliance, its impact on various industries underscores its significa', 'Length': 136, 'Encrypted Data (Binary)': 'b\'\\x85\\x1a\\x83\\xd1\\x8b\\xe5\\xb5\\xba\\x06\\x8e\\xe1`\\x9d\\x8f\\x87\\xefu\\x19\\xa3m\\xb6r\\x82\\x1b\\xe4\\xbb\\xd8\\xb94\\x9ar\\x83\\xacW\\xec\\xf8\\xdd\\x89\\x9c\\xe9\\xea\\r\\xfeElf\\xdc3\\x8e.\\xc7\\x00\\tA\\xd4\\xc7D)?\\x1d\\r2R\\x14\\\\\\xad\\xfb\\xdc\\n\\x8f\\xf2\\x84\\xdcB~I\\xe8\\x15\\xa5\\xf0\\x0e\\xb5ps
f\\xc4\\rI\\xfa\\x87\\xdd\\x85\\x11\\xc2\\xa2\\\\$\\xd9\\xc3\\xdc\\x91\\xd3+,\\x1f8\\x9b\\xd4\\xa4&\\x82\\xe9|\\xbe\\xb6\\xb4}\\xed\\xc0\\xaf\\x1b\\xbd\\xec\\xb0\\xa0\\xb8\\x8b\\x01S\\x19p\\x9e\\xabZ\\x91/\\xf0\\xdc`\\x81\\x1b\\xa8\\xc7^+\\xb4\\xfa\\xd2\\xe4z$\\x9b\\xc2\\xc1x\\xb66*\\x8apYeb\\xca"', 'Encrypted Data (Hex)': '', 'Algorithm': 'AES', 'length': 160, 'entropy': 6.803055907333277, 'freq_top_1_freq': 4, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': 8, 'byte_distribution_mean': 1.322314049586777, 'byte_distribution_std': 0.5780399487618417, 'repetition_count': 0.0, 'avg_hamming_distance': 988.3157894736842, 'bit_zeros_ratio': 0.509375, 'bit_ones_ratio': 0.490625, 'padding_length': 0, 'iv': b'JtY\xbbx\x90V\xfe\xc5\xe0g\xe8&g\x89\xe2', 'mode': 'CBC or other block mode'}
# {'Original Text': "g in their home.\n \n Books fall from shelves,\n \n Dust forms patterns on the floor.\n \n Murph believes it's a ghost,\n \n But Cooper is not so sure.\n \n They de", 'Length': 144, 'Encrypted Data (Binary)': 'b\'\\xe3\\xbe\\xf5\\x95\\xd2\\xce\\x0f\\xa3"j\\x9e-\\xa9\\xbdHj5\\x9a\\x16p\\xc92\\x96\\x8a#mk\\xd8\\xf6\\x95\\xff\\xd8O\\xed\\x1aV\\xbb\\x92\\x8e*\\x90\\xc56\\x98l\\x89}\\x19XK\\xfb\\xf3\\xe3\\x87}-\\x8c\\x02\\x15\\x14\\xda\\x17\\xe9%\\x80\\x036&\\xa3\\xd4\\x17/\\x1d\\x02\\xac2i\\x8d\\xb0\\xfb\\xfc)7\\xc1RT\\xbc\\\'\\x16\\xf7\\xe2\\xf06"8Ec\\x99]D\\\\\\\'\\x8f]\\x9e\\xcf8\\xb1\\xc7\\x052\\x0e2Y\\xb2\\xa0S\\x05\\xb0\\xe9\\xe9\\xf0\\xd4\\x07F\\xce\\xafJs\\x88\\xd2\\xc4\\xbf\\x12\\xd1IX\\x9c\\xd1\\x99\\x88\\xf1\\xf6\\xca\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 144, 'entropy': 6.673329341690056, 'freq_top_1_freq': 4, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': 8, 'byte_distribution_mean': 1.309090909090909, 'byte_distribution_std': 0.5517814874724917, 'repetition_count': 0.006944444444444444, 'avg_hamming_distance': 1008.3529411764706, 'bit_zeros_ratio': 0.5060763888888888, 'bit_ones_ratio': 0.4939236111111111, 'padding_length': 0, 'iv': b'\xe3\xbe\xf5\x95\xd2\xce\x0f\xa3"j\x9e-\xa9\xbdHj', 'mode': 'CBC or other block mode'}
bROV`*\\xad\\xd7\\x9f\\t78WI\\xb3L\\x0f7\\x8b\\xa2cQ\\xe3\\xd7L\\xe0\\xe8\\tk\\x9e\\x00\\xfe\\x11\\x06T\\xd2+\\x14\\xc5\\xa5k\\x88w\\x8e\\xda\\x1f\\x9d\\xfe\\xb0a\\xf2e?\\x9f\\xba\\xe2\\xf7\\xf9_\\xaad\\xf9\\xf2\\x9d0\\xbbNA0\\xbbTI\\xe6\\xe3\\xe3\\x8e\\x9d\\x89\\x89kS\\xcc\\xd9G\\xa9\\xea:q\\xc7:\\xe8\\xe5S\\x07\\xd4\\x97^{3\\x8c\\xb7\\xdf\\n9\\x0fs\\xe3\\xc3\\xba~u\\xb8\\xf3\\x87\\\\\'}\\xe1"', 'Encrypted Data (Hex)': '', 'Algorithm': 'AES', 'length': 160, 'entropy': 6.663901766667712, 'freq_top_1_freq': 4, 'freq_top_2_freq': 4, 'freq_top_3_freq': 4, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': 8, 'byte_distribution_mean': 1.415929203539823, 'byte_distribution_std': 0.7253398802565016, 'repetition_count': 0.0125, 'avg_hamming_distance': 1054.157894736842, 'bit_zeros_ratio': 0.49609375, 'bit_ones_ratio': 0.50390625, 'padding_length': 0, 'iv': b'Y\x1f0u\t:yF\xc2\x99_\x9fB\x15\x01\xfc', 'mode': 'CBC or other block mode'}
# {'Original Text': 'craft. AI-generated music, for example, can analyze existing compositions and create new pieces in the same style, while AI-powered visual art syst', 'Length': 148, 'Encrypted Data (Binary)': "b'o\\xfc\\xb0oT%2\\x12\\xbc\\x88\\xab\\xae\\xe4\\xbb\\xc3X\\xd7\\xf1\\xbd\\x8f\\xe7_j\\x19\\xcc\\xb7\\x13s\\xe5bd&g\\xd07\\xec<\\xbc=\\xf7.\\x0fh:*F\\x96\\x7f\\xb5\\xcb\\xadx\\xa3\\xdb\\x10\\xea\\x15\\xa9\\xb5\\xbe5\\xbeG\\xcd'", 'Encrypted Data (Hex)': '6ffcb06f54253212bc88abaee4bbc358d7f1bd8fe75f6a19ccb71373e562642667d037ec3cbc3df72e0f683a2a46967fb5cbad78a3db10ea15a9b5be35be47cd', 'Algorithm': 'SHA', 'length': 64, 'entropy': 5.875, 'freq_top_1_freq': 2, 'freq_top_2_freq': 2, 'freq_top_3_freq': 2, 'freq_top_4_freq': 2, 'freq_top_5_freq': 1, 'block_size': 8, 'byte_distribution_mean': 1.0666666666666667, 'byte_distribution_std': 0.24944382578492943, 'repetition_count': 0.0, 'avg_hamming_distance': 1006.4285714285714, 'bit_zeros_ratio': 0.44921875, 'bit_ones_ratio': 0.55078125, 'padding_length': 0, 'iv': b'o\xfc\xb0oT%2\x12\xbc\x88\xab\xae\xe4\xbb\xc3X', 'mode': 'CBC or other block mode'}
'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 129, 'entropy': 6.590570956923316, 'freq_top_1_freq': 3, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': None, 'byte_distribution_mean': 1.2524271844660195, 'byte_distribution_std': 0.4969508307599893, 'repetition_count': 0.007751937984496124, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.4951550387596899, 'bit_ones_ratio': 0.5048449612403101, 'padding_length': 0, 'iv': b'L\x82\x8b*\xad"\x9eP\x87[\x97\xf217(c', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'er.\n \n As they pass through the wormhole,\n \n The crew is awestruck by the beauty and mystery of the cosmos.\n \n On the other side, they are face', 'Length': 137, 'Encrypted Data (Binary)': 'b\'\\x8e\\xbc\\xe1\\r"q\\x9b\\xae\\xee\\x02\\x9fU\\xee1\\xa7\\x0b~\\xc2G\\xaf\\x1d\\x17\\xfey\\xe9\\x94[\\x9aG\\xd3\\x19\\\'\\xb0\\xc2\\xa3o\\xd1 w(\\xaf\\xef\\xa4\\x8c\\xdcDkus\\xe2\\xbe0\\xa7\\x9e>\\xf0\\x1aa\\xc1*;\\x95\\x0e&\\xe7\\xf6f\\xf3;j\\xc8\\xd6\\xcdE\\xbfT\\x14\\xb0\\xaf,\\x8bf\\xd4\\x14\\xb4\\xe6\\xa1Y1T&\\xd0_\\x8fi\\xcd\\xc2\\xae\\xc3y<\\x94{;\\xa0R\\x8a\\xd3\\xb5\\x906\\x8f\\x07\\xd8\\xc3>\\x10p\\x8a\\xd2\\x06%\\xafG\\xa8J\\xab*\\x95C\\xc7;K\\xcc\\x1bMm\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 137, 'entropy': 6.634457082928931, 'freq_top_1_freq': 4, 'freq_top_2_freq': 4, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 2, 'block_size': None, 'byte_distribution_mean': 1.2685185185185186, 'byte_distribution_std': 0.5869961429850171, 'repetition_count': 0.0, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.49178832116788324, 'bit_ones_ratio': 0.5082116788321168, 'padding_length': 0, 'iv': b'\x8e\xbc\xe1\r"q\x9b\xae\xee\x02\x9fU\xee1\xa7\x0b', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'ts applications in healthcare, finance, transportation, and entertainment are already having a profound impact, and the possibilities for future innovatio', 'Length': 154, 'Encrypted Data (Binary)': "b'=L\\xf6\\xfe\\xe6b\\x9e\\x80\\xa9\\xc6\\x12\\xd7\\x14\\xa3\\xd2\\xe1\\x92\\x16\\x81\\x10'", 'Encrypted Data (Hex)': '3d4cf6fee6629e80a9c612d714a3d2e192168110', 'Algorithm': 'SHA', 'length': 20, 'entropy': 4.321928094887363, 'freq_top_1_freq': 1, 'freq_top_2_freq': 1, 'freq_top_3_freq': 1, 'freq_top_4_freq': 1, 'freq_top_5_freq': 1, 'block_size': None, 'byte_distribution_mean': 1.0, 'byte_distribution_std': 0.0, 'repetition_count': 0.0, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.5375, 'bit_ones_ratio': 0.4625, 'padding_length': 0, 'iv': b'=L\xf6\xfe\xe6b\x9e\x80\xa9\xc6\x12\xd7\x14\xa3\xd2\xe1', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'puting\n \n Cloud computing offers numerous advantages, but it also presents certain challenges that organizations must address.\n \n Benefits:\n \n Scalabil', 'Length': 145, 'Encrypted Data (Binary)': "b'\\xe3\\xd6\\x11\\x94\\xafd\\x02\\xd6\\xe0`\\xf7Y\\x8dsC,\\x17\\xbc\\x91\\xbb\\x9e\\x13Jnb\\x7f\\xab\\x8e\\x04l\\xbb\\xaa\\xc1\\x05\\xec\\x86\\xf0\\xdd3M\\xc1y[\\\\dmx\\xd7\\x93S*A\\xfb\\xad\\x88\\xbc\\x10\\xc84\\xf7\\xcbt\\x99\\xe8d\\xfd\\xf7\\r\\xday\\xbd\\xf9\\x1e\\xf2\\xc9b\\x9e\\xa2\\xb0\\xf3\\x05\\xca\\xf4H\\x80F\\xe9\\x8a\\x9e\\x8b><+\\xf1\\xcd\\x17\\x99;\\x80H\\xef\\xa6\\x92\\xa3^\\xf8+\\xe8\\xa2\\xad$\\x0b\\xa6\\x9e\\x9fX\\xf6\\xaa\\xa3\\x9d[\\xfa\\xdc\\x8a\\x9e\\xe7\\xf7\\xdd\\xb1_\\xa8\\x7f\\x92\\rK\\xec\\x07 \\xa2\\x80Q\\xe19c\\x10{\\x19\\xfb#x\\x0c\\x84\\x80\\xf0\\xc2\\x89+\\xce\\xc7\\xe8\\xb5\\xf9\\x82\\x82\\xfcO\\xc95\\xb5\\x84x\\xf6A\\xddk\\x9b\\x1a'", 'Encrypted Data (Hex)': '', 'Algorithm': 'AES', 'length': 177, 'entropy': 6.8114532026964625, 'freq_top_1_freq': 5, 'freq_top_2_freq': 4, 'freq_top_3_freq': 4, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': None, 'byte_distribution_mean': 1.416, 'byte_distribution_std': 0.7286590423510848, 'repetition_count': 0.005649717514124294, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.4901129943502825, 'bit_ones_ratio': 0.5098870056497176, 'padding_length': 0, 'iv': b'\xe3\xd6\x11\x94\xafd\x02\xd6\xe0`\xf7Y\x8dsC,', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'eural networks inspired by the structure of the human brain. Deep learning models, such as convolutional neural networks (CNNs) and recurrent ne', 'Length': 144, 'Encrypted Data (Binary)': 'b\'\\xc2\\xf5.\\xa0Q\\x99\\xe3\\x02\\xbeQ\\x18\\x1f\\x19\\xd9^+\\x9f\\xdb\\x91\\xe0\\xcd\\xe4\\xc9\\x9dM\\xc9D;\\xee\\t}4g8\\xfe\\x90K\\x02EO(\\xedH"\\x92\\xbf\\xa8\\x82\\xbc9\\x05\\xd6\\xce\\n\\x064\\xee\\xc6EA\\x15\\xed\\xa0\\xc8\'', 'Encrypted Data (Hex)': 'c2f52ea05199e302be51181f19d95e2b9fdb91e0cde4c99d4dc9443bee097d346738fe904b02454f28ed482292bfa882bc3905d6ce0a0634eec6454115eda0c8', 'Algorithm': 'SHA', 'length': 64, 'entropy': 5.75, 'freq_top_1_freq': 2, 'freq_top_2_freq': 2, 'freq_top_3_freq': 2, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': 8, 'byte_distribution_mean': 1.1428571428571428, 'byte_distribution_std': 0.34992710611188266, 'repetition_count': 0.0, 'avg_hamming_distance': 1224.857142857143, 'bit_zeros_ratio': 0.525390625, 'bit_ones_ratio': 0.474609375, 'padding_length': 0, 'iv': b'\xc2\xf5.\xa0Q\x99\xe3\x02\xbeQ\x18\x1f\x19\xd9^+', 'mode': 'CBC or other block mode'}
# {'Original Text': 'tutions manage risk, detect fraud, and provide personalized financial services. Algorithms can sift through enormous amounts of transaction data to ide', 'Length': 151, 'Encrypted Data (Binary)': "b'$X\\xc6\\x89\\x10\\xe9\\x0c\\xf2\\x92\\x02i\\xe0\\xa1\\x82Cq\\x03\\x9b\\x85\\xe6@\\x1f\\x89\\\\u\\xbc\\xc5\\x8d\\x06\\xd1\\xdf<'", 'Encrypted Data (Hex)': '2458c68910e90cf2920269e0a1824371039b85e6401f895c75bcc58d06d1df3c', 'Algorithm': 'SHA', 'length': 32, 'entropy': 4.9375, 'freq_top_1_freq': 2, 'freq_top_2_freq': 1, 'freq_top_3_freq': 1, 'freq_top_4_freq': 1, 'freq_top_5_freq': 1, 'block_size': 8, 'byte_distribution_mean': 1.032258064516129, 'byte_distribution_std': 0.17668469596940847, 'repetition_count': 0.0, 'avg_hamming_distance': 1000.3333333333334, 'bit_zeros_ratio': 0.56640625, 'bit_ones_ratio': 0.43359375, 'padding_length': 0, 'iv': b'$X\xc6\x89\x10\xe9\x0c\xf2\x92\x02i\xe0\xa1\x82Cq', 'mode': 'CBC or other block mode'}
# {'Original Text': 'ing people of color, leading to concerns about its use in law enforcement and surveillance. Additionally, the increasing automation of jobs poses', 'Length': 145, 'Encrypted Data (Binary)': "b'VE\\x18\\xdb\\x87\\x12\\x1fm\\xb6\\x1dL\\t\\xa6R\\xb6U\\xad\\xc7`\\xe7'", 'Encrypted Data (Hex)': '564518db87121f6db61d4c09a652b655adc760e7', 'Algorithm': 'SHA', 'length': 20, 'entropy': 4.221928094887362, 'freq_top_1_freq': 2, 'freq_top_2_freq': 1, 'freq_top_3_freq': 1, 'freq_top_4_freq': 1, 'freq_top_5_freq': 1, 'block_size': None, 'byte_distribution_mean': 1.0526315789473684, 'byte_distribution_std': 0.22329687826943603, 'repetition_count': 0.0, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.50625, 'bit_ones_ratio': 0.49375, 'padding_length': 0, 'iv': b'VE\x18\xdb\x87\x12\x1fm\xb6\x1dL\t\xa6R\xb6U', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'wing, with its unique blend of athleticism, strategy, and the picturesque beach setting attracting fans from all walks of life.\n\nV', 'Length': 130, 'Encrypted Data (Binary)': 'b\'V[\\xa1/I\\xd3LY\\t\\xa8\\x13p\\x0f\\xe3\\xbfX@\\xb9\\xf2\\xf2"]N\\xc0\\xf6\\x80x\\xfbD\\xf5\\xa4c\\x99\\xd7\\x02\\x037"\\xca4ID\\xaeN\\x1d-\\xa9~\\xc6\\x05_~\\x9a\\xa4b[A\\xb5\\xc0uq\\x05a\\xea\\xb0lZ\\xd3\\x1aCto<\\r\\x8b\\xc0\\x93uP(\\tE\\xd2\\x88\\x0513I\\xdf\\\\\\xa8*\\x19\\x08\\xb8\\x06\\xc9\\xf9\\xdfh\\xcc\\x97-Y\\xaa\\x86q\\xc7\\xeb`\\xdd\\x14\\xe1"F\\xc9uO\\xc1\\x878
 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': 8, 'byte_distribution_mean': 1.5238095238095237, 'byte_distribution_std': 0.7315376902732008, 'repetition_count': 0.0, 'avg_hamming_distance': 1005.5806451612904, 'bit_zeros_ratio': 0.509765625, 'bit_ones_ratio': 0.490234375, 'padding_length': 0, 'iv': b"\x8cs\xd0F\xd4h\xba\xa2\x10.\xb2'v\xf5\xc2\xd0", 'mode': 'CBC or other block mode'}
# {'Original Text': 'ntify unusual patterns, flagging potentially fraudulent activity before it causes significant harm. Similarly, AI-driven investment platforms analyze market', 'Length': 156, 'Encrypted Data (Binary)': "b'\\x824D\\xcd\\xbc\\x0c\\xf2\\x87\\xa5\\xb8\\xd4M\\xff\\xe3\\xe4\\x98\\xa7V\\xf8\\xb9\\x124\\x138\\x9a\\x81\\xd9NxF?\\x8b'", 'Encrypted Data (Hex)': '823444cdbc0cf287a5b8d44dffe3e498a756f8b9123413389a81d94e78463f8b', 'Algorithm': 'SHA', 'length': 32, 'entropy': 4.9375, 'freq_top_1_freq': 2, 'freq_top_2_freq': 1, 'freq_top_3_freq': 1, 'freq_top_4_freq': 1, 'freq_top_5_freq': 1, 'block_size': 8, 'byte_distribution_mean': 1.032258064516129, 'byte_distribution_std': 0.17668469596940847, 'repetition_count': 0.0, 'avg_hamming_distance': 1065.3333333333333, 'bit_zeros_ratio': 0.5078125, 'bit_ones_ratio': 0.4921875, 'padding_length': 0, 'iv': b'\x824D\xcd\xbc\x0c\xf2\x87\xa5\xb8\xd4M\xff\xe3\xe4\x98', 'mode': 'CBC or other block mode'}
# {'Original Text': 'Interstellar: A Journey Through Space and Time\n \n In a future not too distant from our own, Earth is on the brink of collapse.\n \n Crops are', 'Length': 136, 'Encrypted Data (Binary)': 'b"I\\x04]\\xaf\\xb4\\xddC\\xe7n\\xcc4\\x90=\\xba\\xda\\xd9\\xac\\xe0(P\\xaa\\xa0\\xc4\\xa9\'\\x8czi\\xb3m\\x92\\x91;\\x984~\\xfc\\xf3\\xb8\\xb4\\\\\\xfbL\\x00,\\xdf\\xbf\\x91\\xe7\\x97]P\\xf8P5\\x8aY\\xd0jm\\xb2\\x84\\xc2\\\\\\xbf\\x12H\\x01M\\xae\\x18\\x15^\\xc0\\xd5\\x14*G\\x00\\xa44`q\\x90\\xe9\\x02}\\x91^?/\\xc1\\xfa\\xf1XM\\xc8\\xe8\\xbb4\\x1f\\xa7\\xa7\\x92f;\\xe7B\\xd1i)$\\x16\\xed*\\xae\\xb2@\\xb4\\xa68\\xcd\\x0b\\xc9&U;\\x82\\xd2\\xa6qgR;\\x95n"', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 136, 'entropy': 6.57996615001023, 'freq_top_1_freq': 4, 'freq_top_2_freq': 4, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': 8, 'byte_distribution_mean': 1.2952380952380953, 'byte_distribution_std': 0.6313071778733924, 'repetition_count': 0.007352941176470588, 'avg_hamming_distance': 984.75, 'bit_zeros_ratio': 0.5165441176470589, 'bit_ones_ratio': 0.4834558823529412, 'padding_length': 0, 'iv': b'I\x04]\xaf\xb4\xddC\xe7n\xcc4\x90=\xba\xda\xd9', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'very industry today. The journey began in the mid-20th century when pioneers like Alan Turing and John McCarthy started exploring the idea of creatin', 'Length': 149, 'Encrypted Data (Binary)': 'b"\\xb8S]\\xf1\\xb1\\xb6<>\\x9bgg\\xd416\\xdc\\xac\\xaf;\\xba\\x11 (\\x8e\\xd1\\xe4H0\\x18\\x82g\\x06\\x85|\\x13\'s\\xef\\x89[8\\xf0\\x95_\\xe3F\\xb50\\xbf*\\xdcf=\\x9d\\x89`\\xa9\\xfe\\xb15\\xc6p\\x1b&\\x12"', 'Encrypted Data (Hex)': 'b8535df1b1b63c3e9b6767d43136dcacaf3bba1120288ed1e4483018826706857c132773ef895b38f0955fe346b530bf2adc663d9d8960a9feb135c6701b2612', 'Algorithm': 'SHA', 'length': 64, 'entropy': 5.800704882778696, 'freq_top_1_freq': 3, 'freq_top_2_freq': 2, 'freq_top_3_freq': 2, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': 8, 'byte_distribution_mean': 1.103448275862069, 'byte_distribution_std': 0.3566924287168483, 'repetition_count': 0.015625, 'avg_hamming_distance': 954.1428571428571, 'bit_zeros_ratio': 0.501953125, 'bit_ones_ratio': 0.498046875, 'padding_length': 0, 'iv': b'\xb8S]\xf1\xb1\xb6<>\x9bgg\xd416\xdc\xac', 'mode': 'CBC or other block mode'}
# {'Original Text': 'cilitates remote access to applications and data from anywhere with an internet connection. This accessibility enhances collaboration', 'Length': 133, 'Encrypted Data (Binary)': 'b\'\\xa3\\x16\\xc4N\\xc2\\xd5\\xa9\\xc9p\\xa6]\\x17u\\xcbn\\xb2\\tb\\xea\\x1e|\\x80\\xfe\\x9d\\xb0\\xe9\\x16K\\x90k\\x85\\xb6\\xf5\\xb6\\x8e\\x06\\x8d\\xb2\\xc7m\\x12S\\x10\\xb4\\x141Y%\\xcb\\xce\\x8e\\x16]\\xe8\\xa22\\xab\\x8609\\xc7\\xf6\\x1cTz\\x11-K;\\x9f,\\x0f3_\\xaeG\\xa1\\x02\\xf2P5]\\xd5\\x80\\xb6f\\tSJ\\xe7#"\\xc83[\\xa3s\\xcb\\xb2\\xb3\\xf3+\\xca\\x9c\\xf4\\xe0\\xb4|\\xee\\xebr\\xba\\xc2\\x1c\\xect\\xbd\\xd9\\xb29\\xfa\\x9c\\xc7O\\xbeH\\xdf\\x84C{)\\x18\\xc7\\xa9\\xfc\\xf93be\\xc4\\xb2A\\n^\\x18\\x8c\\xcc\\x86/5\\x01\\xe0\\x90\\xfcYG\\xff\\x90\\x0b6\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'AES', 'length': 160, 'entropy': 6.733559560591004, 'freq_top_1_freq': 5, 'freq_top_2_freq': 4, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size
c3\\xdd\\xb7:swG\\xa4\\xde\\x86\\x8d]\\x8f\\x01\\x90%\\x96v\\x94\\x88#~\\xecu\\xa0\\xc3}Ub\\xc5^Q\\xbb\\xc8\\xebd\\x7fT1\\xb0\\xab\\x10\\x92\\x15\\x02KL\\xcb\\x10\\x08,\\xa1\\xacTS\\xa1\\xb4\\xddQ\\xa3\\xc74\\rat\\x90F`\\xb8\\x0f\\x9d\\x88\\x11\\xe1\\xdd\\x07\\xc5vs\\xde\\x15gQ\\xee\\x1c\\xa9^A\\xac6fX\\x14\\xc9wS\\xbfQ\\x84\\x7f\\xce\'', 'Encrypted Data (Hex)': '...', 'Algorithm': 'RSA', 'length': 256, 'entropy': 7.188329273518898, 'freq_top_1_freq': 5, 'freq_top_2_freq': 5, 'freq_top_3_freq': 4, 'freq_top_4_freq': 4, 'freq_top_5_freq': 4, 'block_size': 8, 'byte_distribution_mean': 1.5609756097560976, 'byte_distribution_std': 0.8204335703197152, 'repetition_count': 0.00390625, 'avg_hamming_distance': 934.5806451612904, 'bit_zeros_ratio': 0.5009765625, 'bit_ones_ratio': 0.4990234375, 'padding_length': 0, 'iv': b'w#\xe8(\x9dc\x18\xdeA\xb2\xb1\xde\xcc\xe6*,', 'mode': 'CBC or other block mode'}
# ...
# {'Original Text': "sponsive to the needs of their residents.\n \n AI's influence extends beyond practical applications into creative fields as well. Artis", 'Length': 131, 'Encrypted Data (Binary)': 'b\'D\\x84"I&\\xd0\\x94\\xa9\\x8d\\xfe\\xc9>w\\x83?Y\\x94\\x8e\\xc2\\x95\\xe5\\xf4\\xdd-\\xac\\x01/Bm 8w\'', 'Encrypted Data (Hex)': '4484224926d094a98dfec93e77833f59948ec295e5f4dd2dac012f426d203877', 'Algorithm': 'SHA', 'length': 32, 'entropy': 4.875, 'freq_top_1_freq': 2, 'freq_top_2_freq': 2, 'freq_top_3_freq': 1, 'freq_top_4_freq': 1, 'freq_top_5_freq': 1, 'block_size': 8, 'byte_distribution_mean': 1.0666666666666667, 'byte_distribution_std': 0.24944382578492943, 'repetition_count': 0.0, 'avg_hamming_distance': 1165.3333333333333, 'bit_zeros_ratio': 0.5234375, 'bit_ones_ratio': 0.4765625, 'padding_length': 0, 'iv': b'D\x84"I&\xd0\x94\xa9\x8d\xfe\xc9>w\x83?Y', 'mode': 'CBC or other block mode'}
# {'Original Text': 'gal implications of storing and processing data in different jurisdictions.\n \n Impact of Cloud Computing on Industries\n \n Cloud computin', 'Length': 132, 'Encrypted Data (Binary)': "b'1^\\x01/\\xd0\\x0b4U\\x9a\\xc4\\x90g\\xd5@\\xfe\\xdeS\\xca\\xb5\\x12\\x13\\xbe\\x04\\xd3\\x86J\\xd3?\\x87`\\x1c{0Jo\\x17\\x7fI\\xad\\x137\\xd2\\xe8\\xd1\\x0by\\x15z\\xf3Zvk\\x030\\x90\\x8c&G\\x1f\\xc6\\xf9\\xe6\\xdck\\x0e\\x9f\\x1d\\x8c\\xed\\xba\\xee\\x13\\xb0\\xb4i\\xda\\xbc(:\
xbd\\x8b\\xdcl\\xf3\\x98\\x92\\x95\\x04\\x01\\x8f\\x885\\x17\\xa05bw\\xc8\\x82\\xc1\\xe7\\x8cv\\xdd\\xd9\\xf5p\\xbf\\xc3\\xc6\\xe0g\\xfeF1\\xa9@\\xfe.E\\x03\\xdb\\x1b\\xf4ty\\xcf\\xac\\xe0\\x1e@)\\x83\\x96\\xa4\\x91\\x80\\xac>\\xa0\\xa5\\xebN$v\\xaf\\xafxksX.+w\\xff_\\x0bJd\\x90\\xa1\\x00\\x12\\xf9\\t\\x81Jri\\xf2\\xd3O\\n\\xf19@\\xf6\\xa5'", 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 150, 'entropy': 6.81045277381478, 'freq_top_1_freq': 4, 'freq_top_2_freq': 3, 'freq_top_3_freq': 2, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': None, 'byte_distribution_mean': 1.25, 'byte_distribution_std': 0.5041494487418058, 'repetition_count': 0.006666666666666667, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.4975, 'bit_ones_ratio': 0.5025, 'padding_length': 0, 'iv': b'\xc2O\xec\xcdr\xd5\x8a\xff\xb3\xbd\x875\xf5\x98\xf8\xa6', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'orce that binds them all together.\n \n With Cooperâ€™s help,\n \n Murph solves the equation,\n \n Unlocking the key to humanityâ€™s survival.\n \n Earthâ€™s population is save', 'Length': 154, 'Encrypted Data (Binary)': 'b\'\\x8b\\x8fc3\\x1a3\\xba_\\x0b7\\xc0\\xc9\\xdcx&\\xe5d\\xc1+\\x00a\\xab\\x11G&\\xbcE\\xfe\\xab\\xed\\xde\\x04\\xcf\\x85M\\xdf\\n\\x9a_\\x84y\\xf9\\xe7\\x90)cYW\\xd9\\xf5\\x1c\\xcb\\xee)\\xa1\\xb2\\xe7\\xb7\\xbb\\xa8x\\x80\\xaa`\\n\\xb5\\xf1_*\\x1ep\\xf5p[\\xb0z\\xfd(\\xf0\\xfa\\xf20t\\xe9\\xd8YX"\\x8f\\xf2w0R\\x04,\\xee\\x83\\xe9q\\xfb\\xe2"V\\x03\\xc5\\x00\\x1b\\x93x\\xf8\\xd9\\x97\\x07_\\xc4\\xab\\xaa\\x83\\xf3N\\xa1K4O\\xd4\\x16\\xcal\\xb2|\\x00\\xde\\xd6\\x96\\xb9\\x19v8\\xf0\\xe1\\xa0\\xa1\\xda\\xa13\\x9e{5\\x05x\\x93"w6a\\xac\\x10\\xc4|\\xb5\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 160, 'entropy': 6.728055907333276, 'freq_top_1_freq': 4, 'freq_top_2_freq': 4, 'freq_top_3_freq': 4, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': 8, 'byte_distribution_mean': 1.3675213675213675, 'byte_distribution_std': 0.6742934332757613, 'repetition_count': 0.0, 'avg_hamming_distance': 1065.1052631578948, 'bit_zeros_ratio': 0.5, 'bit_ones_ratio': 0.5, 'padding_length': 0, 'iv': b'\x8b\x8fc3\x1a3\xba_\x0b7\xc0\xc9\xdcx&\xe5', 'mode': 'CBC or other block mode'}
\\xef\\xe93fXl\\x8b\\xb93\\x0f\\xf7\\x1b\\xed\\xcf,\\x8d\\xac\\x9f3(\\xfa\\x11\\x86\\xff\\x18Y\\xe1O\\xf5\\xf0Z\\xf6\\x02\\xff\\xf6\\x05\\x8d\\x10\'', 'Encrypted Data (Hex)': '...', 'Algorithm': 'RSA', 'length': 512, 'entropy': 7.6336719925080585, 'freq_top_1_freq': 7, 'freq_top_2_freq': 7, 'freq_top_3_freq': 6, 'freq_top_4_freq': 6, 'freq_top_5_freq': 5, 'block_size': 8, 'byte_distribution_mean': 2.226086956521739, 'byte_distribution_std': 1.2515094855567668, 'repetition_count': 0.00390625, 'avg_hamming_distance': 995.015873015873, 'bit_zeros_ratio': 0.490478515625, 'bit_ones_ratio': 0.509521484375, 'padding_length': 0, 'iv': b'|\xc1\xd2^2\x03\xf6\x0b\xd7-\xdf\xdf\xdf\x89\xba\x0e', 'mode': 'CBC or other block mode'}
# {'Original Text': 'scalability, and cost-effectiveness of cloud computing have made it an integral part of modern IT strategies, enabling businesses to innovate, scale, and', 'Length': 154, 'Encrypted Data (Binary)': 'b\'\\xa8\\xe6O4\\xab\\xe4\\xcfS\\x05\\x04\\x12\\x9c\\xe4\\xc7\\xbdB:\\x869_\\x18\\x13\\xcb\\xa7\\x1b\\x18\\x05\\xa5\\x15\\xbf\\xb1\\xc6;\\xe1#\\xb4>\\xb2\\x16\\xe1\\xd9Wox\\x027\\x98\\xe3\\x1f\\x93\\x13\\x07\\x17:\\x14\\xb7m\\x12\\x83k@\\xea\\\'\\x12P\\xa1\\xf6\\xa0\\xaa\\n\\xad\\xddQ\\xf9\\x14\\xb3G\\xb9\\xdcm:G|\\xad\\xf4)\\xe3\\xab\\x00A\\x02M\\x187\\xbe\\xac\\x19\\xb1\\xb1x\\xe9a\\x13X>\\x8d\\x99\\xac\\x14\\xc9\\x14\\xa3\\xcf\\x15@\\xb4\\xfa"\\xe4!\\xbe\\xf4\\xc4\\xbaBx)M\\x0f\\xc5\\x8d\\xfeTE\\x83A\\xd4\\x16\\x81F[9w\\xea\\x91\\xe7\\xa5\\x8b4qN\\xef\\x14\\xb9\\xfeA\\xebU\\x14#\\x19-\\xb0\\xb7?A\\xdepK\\x8f\\x1f\\xd8\\xf47Ax\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'AES', 'length': 176, 'entropy': 6.691485507864174, 'freq_top_1_freq': 6, 'freq_top_2_freq': 5, 'freq_top_3_freq': 4, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': 8, 'byte_distribution_mean': 1.5042735042735043, 'byte_distribution_std': 0.8435165669384839, 'repetition_count': 0.005681818181818182, 'avg_hamming_distance': 1014.3333333333334, 'bit_zeros_ratio': 0.5134943181818182, 'bit_ones_ratio': 0.4865056818181818, 'padding_length': 0, 'iv': b'\xa8\xe6O4\xab\xe4\xcfS\x05\x04\x12\x9c\xe4\xc7\xbdB', 'mode': 'CBC or other block mode'}
# {'Original Text': 'tâ€™s at stake.\n \n Humanityâ€™s future depends on them.\n \n As the mission draws to a close,\n \n The crew makes one final, desperate gamble.', 'Length': 130, 'Encrypted Data (Binary)': 'b\'\\x95s\\x8fJ\\x8c\\xf2cXF\\xcb\\xedM\\x9e\\xdb\\x8e\\xae\\xcd\\x9e)\\xfe\\xb8(\\x90\\x994\\x8c\\x97\\xe69:7\\x81W\\x89.\\xe8\\xb3\\xa0\\xa0e\\x91\\xf5\\x83)\\x99\\x08\\x0f\\xf0\\xce\\xe4w\\xe1\\xdc@\\x126\\x15\\x01\\x05\\x87\\xa4h\\x89=\\xfe7h\\x9e\\x9b\\xdeU\\xb9az\\xc8\\xb0y\\\'\\xdd\\xc0\\xac\\xd8\\xdey1\\xc2w)nq\\x16I\\xfc\\x80:\\x8b>\\x1c^\\xad\\x9a\\x18\\xd6\\x01\\xca\\x9eR*\\xa9A\\x89\\x07\\xc0">I\\x96\\\\&\\xc8\\xd0\\xecB\\xeb\\xe3\\xe9\\x11EWB\\xad;\\xb3 \'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 134, 'entropy': 6.6518371381866785, 'freq_top_1_freq': 4, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': None, 'byte_distribution_mean': 1.2407407407407407, 'byte_distribution_std': 0.5247639746409168, 'repetition_count': 0.007462686567164179, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.5177238805970149, 'bit_ones_ratio': 0.4822761194029851, 'padding_length': 0, 'iv': b'\x95s\x8fJ\x8c\xf2cXF\xcb\xedM\x9e\xdb\x8e\xae', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'Amelia,\n \n Who is on another planet,\n \n Preparing humanityâ€™s new home.\n \n Interstellar is a story of exploration,\n \n Of survival,\n \n And of love.\n \n It is a tale o', 'Length': 152, 'Encrypted Data (Binary)': 'b\'\\x87\\x7f\\xd1}oe\\xcfz\\xd4\\xbcC\\x9cl\\n\\x133\\xebCh,\\x84\\xa8:\\xb2\\x0c\\xf64\\x96\\xf4\\\\\\xfa\\xd3S1\\xe20U\\xac(=\\xcd\\x84\\xd8\\t\\x0ek\\x01\\x1c\\x80\\x1c[fT\\x16\\x0b\\xeeyVYY\\xecu`\\xfex]D!\\xd0\\xb8\\xe6\\x84J\\xa6?\\xd4\\xda\\xc59\\x81\\xf2D\\x9bv\\x8ds\\x92\\xae;\\xe7\\xf6f\\xdd\\xf3\\x9f\\x9e\\x1c\\\'|\\x13\\x97\\xc9\\xba\\xe2\\xe6M"\\xc0\\x04d@31\\x0b;\\xf2!\\xe56\\x10\\x00\\xbe\\xd6_\\xce\\xcc\\xc3\\x14\\xf2\\x80\\x049L\\xc4\\xe7%2\\xeas\\x9cUA\\x89\\xdca\\xbdh\\xa0\\xefF\\xf1K:\\xf2\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 154, 'entropy': 6.854385404303182, 'freq_top_1_freq': 4, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': None, 'byte_distribution_mean': 1.2419354838709677, 'byte_distribution_std': 0.5138558813572256, 'repetition_count': 0.006493506493506494, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.5113636363636364, 'bit_ones_ratio': 0.48863636363636365, 'padding_length': 0, 'iv': b'\x87\x7f\xd1}oe\xcfz\xd4\xbcC\x9cl\n\x133', 'mode': 'Unknown or Stream Cipher'}

# %%
df = pd.DataFrame(features_dataset)
df.head()
df.to_excel('Feature_Engineering_Testing_New.xlsx', index=False)
