# %%
# %pip install os csv cryptography
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
import random

def split_text(text, min_size=128, max_size=160):
    blocks = []
    while text:
        # Choose a random block size between min_size and max_size
        block_size = random.randint(min_size, max_size)

        # Append the block to the list
        blocks.append(text[:block_size])
        text = text[block_size:]

    return blocks

# The ciphertext text provided
ciphertext = """

Cloud computing has revolutionized the way individuals and organizations access and manage computing resources. At its core, cloud computing involves delivering computing services—such as servers, storage, databases, networking, software, and analytics—over the internet, or "the cloud." This model allows users to access these resources on-demand, without the need for physical infrastructure or hardware investments. The flexibility, scalability, and cost-effectiveness of cloud computing have made it an integral part of modern IT strategies, enabling businesses to innovate, scale, and respond to market changes more rapidly than ever before.

The concept of cloud computing is not entirely new; its roots can be traced back to the early days of computing when time-sharing systems allowed multiple users to access a single computer’s resources. However, the modern era of cloud computing began in the early 2000s with the advent of companies like Amazon Web Services (AWS), Microsoft Azure, and Google Cloud Platform (GCP). These platforms pioneered the public cloud model, which offers services to a broad audience over the internet. Since then, cloud computing has evolved, encompassing various models and services that cater to different needs and preferences.

Types of Cloud Computing Models

Cloud computing is generally categorized into three main service models and four deployment models, each offering different levels of control, flexibility, and management.

Service Models:

Infrastructure as a Service (IaaS): IaaS provides virtualized computing resources over the internet. Users can rent virtual machines, storage, and networking components as needed. IaaS offers the most control over the underlying infrastructure and is ideal for businesses that need to customize their environments. Examples of IaaS providers include AWS EC2, Google Compute Engine, and Microsoft Azure Virtual Machines.

Platform as a Service (PaaS): PaaS offers a higher level of abstraction by providing a platform that includes both hardware and software tools for application development. Users can develop, deploy, and manage applications without worrying about the underlying infrastructure. PaaS solutions are designed to streamline development and deployment processes, making it easier for developers to focus on coding and application logic. Notable PaaS offerings include Google App Engine, Microsoft Azure App Service, and Heroku.

Software as a Service (SaaS): SaaS delivers software applications over the internet, typically on a subscription basis. Users access these applications via web browsers, eliminating the need for local installation and maintenance. SaaS applications are managed by the service provider, ensuring regular updates, security patches, and support. Popular SaaS examples include Salesforce, Google Workspace, and Microsoft Office 365.

Deployment Models:

Public Cloud: In a public cloud model, services are delivered over the internet and shared among multiple users or organizations. Public clouds are operated by third-party providers who own and manage the infrastructure. This model is cost-effective and scalable but may raise concerns about data security and privacy. Examples include AWS, Azure, and GCP.

Private Cloud: A private cloud is dedicated to a single organization and can be hosted either on-premises or by a third-party provider. It offers greater control and customization compared to public clouds and is suitable for organizations with specific security, compliance, or performance requirements. Private clouds can be more expensive but provide enhanced security and privacy.

Hybrid Cloud: Hybrid clouds combine elements of both public and private clouds, allowing organizations to leverage the benefits of both models. This approach enables businesses to maintain sensitive data on a private cloud while utilizing public cloud resources for less critical applications or workloads. Hybrid clouds offer flexibility and scalability while addressing specific security and compliance needs.

Community Cloud: A community cloud is shared among several organizations with similar interests or requirements, such as regulatory compliance or industry-specific needs. It can be managed by one of the participating organizations or by a third party. Community clouds provide a cost-effective solution for organizations with common goals while maintaining a level of control and privacy.

Benefits and Challenges of Cloud Computing

Cloud computing offers numerous advantages, but it also presents certain challenges that organizations must address.

Benefits:

Scalability and Flexibility: Cloud computing allows organizations to scale their resources up or down based on demand. This elasticity ensures that businesses can handle varying workloads without over-provisioning or underutilizing resources. Cloud services can be quickly adjusted to meet changing needs, enabling businesses to respond to market fluctuations and growth opportunities.

Cost Savings: By adopting cloud computing, organizations can reduce capital expenditures associated with purchasing and maintaining physical hardware. Cloud services typically operate on a pay-as-you-go or subscription model, allowing businesses to pay only for the resources they use. This model eliminates the need for large upfront investments and reduces ongoing operational costs.

Accessibility and Collaboration: Cloud computing facilitates remote access to applications and data from anywhere with an internet connection. This accessibility enhances collaboration among teams, as multiple users can work on the same project simultaneously, regardless of their location. Cloud-based tools and platforms support real-time communication and collaboration, improving productivity and efficiency.

Automatic Updates and Maintenance: Cloud service providers handle software updates, security patches, and system maintenance, ensuring that users have access to the latest features and improvements. This managed approach reduces the burden on IT teams and helps maintain the security and reliability of cloud services.

Challenges:

Security and Privacy: Security is a major concern for cloud computing, as sensitive data is stored and transmitted over the internet. Organizations must ensure that their cloud service providers implement robust security measures, such as encryption, access controls, and regular security audits. Privacy concerns also arise, particularly when dealing with regulatory compliance and data protection laws.

Downtime and Reliability: While cloud service providers strive to offer high availability, downtime and service interruptions can occur. Organizations must assess the reliability of their chosen cloud providers and implement strategies for mitigating the impact of potential outages. Service Level Agreements (SLAs) can provide assurances regarding uptime and performance, but organizations should have contingency plans in place.

Vendor Lock-In: Relying on a single cloud provider can lead to vendor lock-in, making it difficult to migrate data and applications to another provider. Organizations should carefully consider the implications of vendor lock-in and explore options for minimizing dependency, such as using open standards and multi-cloud strategies.

Compliance and Legal Issues: Compliance with data protection regulations and industry standards is a critical consideration for organizations using cloud services. Cloud providers and customers must work together to ensure that data handling practices meet regulatory requirements. Organizations should be aware of the legal implications of storing and processing data in different jurisdictions.

Impact of Cloud Computing on Industries

Cloud computing has had a profound impact on various industries, transforming the way businesses operate and innovate. Some notable examples include:

Healthcare: In the healthcare industry, cloud computing has enabled the development of electronic health records (EHRs), telemedicine platforms, and data analytics tools. Cloud-based solutions facilitate the secure storage and sharing of patient information, improving care coordination and access to medical data. Additionally, cloud computing supports research and development efforts by providing computational resources for analyzing large datasets and conducting complex simulations.

Finance: The financial services sector has embraced cloud computing to enhance customer experiences, streamline operations, and improve risk management. Cloud-based solutions enable real-time data processing, fraud detection, and personalized financial services. Financial institutions also use cloud computing to manage regulatory compliance and support high-frequency trading platforms.

Retail: Retailers leverage cloud computing to optimize supply chain management, enhance customer engagement, and analyze consumer behavior. Cloud-based solutions enable inventory management, personalized marketing campaigns, and data-driven insights into sales trends. Retailers can also use cloud services to support e-commerce platforms and manage large volumes of transaction data.

Education: Cloud computing has transformed the education sector by providing access to online learning platforms, collaborative tools, and digital resources. Educational institutions use cloud-based solutions to deliver remote learning, facilitate virtual classrooms, and support student collaboration. Cloud computing also enables the development of adaptive learning technologies and data-driven insights into student performance.

Government: Government agencies have adopted cloud computing to improve service delivery, enhance data management, and support digital transformation initiatives. Cloud-based solutions enable the efficient management of public services, such as citizen engagement platforms, data analytics for policy-making, and secure data storage for sensitive information.

Conclusion

Cloud computing has emerged as a transformative force in the technology landscape, offering a wide range of benefits and opportunities for businesses and individuals alike. Its flexibility, scalability, and cost-effectiveness have made it an essential component of modern IT strategies. While cloud computing presents certain challenges, such as security and compliance, its impact on various industries underscores its significance in driving innovation and improving operational efficiency. As technology continues to evolve, cloud computing will likely play an increasingly important role in shaping the future of computing and digital transformation.


"""

# Split the text into blocks
blocks = split_text(ciphertext)
length_of_list = len(blocks)

blocks, length_of_list
# Out:
# (['\n\nCloud computing has revolutionized the way individuals and organizations access and manage computing resources. At its core, cloud computi',
#   'ng involves delivering computing services—such as servers, storage, databases, networking, software, and analytics—over the internet, or "th',
#   'e cloud." This model allows users to access these resources on-demand, without the need for physical infrastructure or hardware investments. The flexibility, ',
#   'scalability, and cost-effectiveness of cloud computing have made it an integral part of modern IT strategies, enabling businesses to innovate, scale, and ',
#   'respond to market changes more rapidly than ever before.\n\nThe concept of cloud computing is not entirely new; its roots can be traced back to the e',
#   'arly days of computing when time-sharing systems allowed multiple users to access a single computer’s resources. However, the mo',
# ...

# %%
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from cryptography.hazmat.primitives import padding
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.backends import default_backend
import os
import random
import csv

crypto_terms = blocks

def aes_encrypt_with_cryptography(input_data):
    # Vary key size: 128-bit, 192-bit, 256-bit
    key_size = random.choice([16, 24, 32])  # 16 bytes = 128-bit, 24 bytes = 192-bit, 32 bytes = 256-bit
    key = os.urandom(key_size)  # Random key generation

    # Vary mode of operation: CBC, GCM
    aes_mode = random.choice([modes.CBC, modes.GCM])

    # Generate random IV
    iv = os.urandom(16)

    input_data = input_data.encode('utf-8')

    if aes_mode == modes.CBC:
        cipher = Cipher(algorithms.AES(key), aes_mode(iv), backend=default_backend())
        encryptor = cipher.encryptor()
        padder = padding.PKCS7(algorithms.AES.block_size).padder()
        padded_data = padder.update(input_data) + padder.finalize()
        ciphertext = encryptor.update(padded_data) + encryptor.finalize()
        final = iv + ciphertext
        return final, final.hex(), key_size, aes_mode, iv  # IV + ciphertext
    else:
        cipher = Cipher(algorithms.AES(key), aes_mode(iv), backend=default_backend())
        encryptor = cipher.encryptor()
        ciphertext = encryptor.update(input_data) + encryptor.finalize()
        tag = encryptor.tag
        final = iv + ciphertext + tag
        return final, final.hex(), key_size, aes_mode, iv  # IV + ciphertext + tag

def generate_encrypted_dataset(num_texts=len(crypto_terms)):
    dataset = []

    for _ in range(num_texts):
        # Choose a random cryptography term as the original plaintext
        original_text = random.choice(crypto_terms)
        crypto_terms.remove(original_text)

        # Encrypt the text using RSA
        encrypted_data, encrypted_hex, key_size, aes_mode, iv = aes_encrypt_with_cryptography(original_text)

        # Append row with original text, encrypted binary, encrypted hex, and padding used
        dataset.append([original_text, len(original_text), encrypted_data, encrypted_hex, key_size, aes_mode, iv, 'AES'])

    return dataset

# Generate dataset with crypto-related terms
rsa_dataset = generate_encrypted_dataset()

# Export dataset to CSV
with open('rsaa1_encrypted1234569_dataset.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Original Text", "Length", "Encrypted Data (Binary)", "Encrypted Data (Hex)", "Key Size", "AES_Mode", "Intilisation_Vector", "Algorithm"])
    for row in rsa_dataset:
        writer.writerow(row)
