# %%
# %pip install os csv cryptography
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
import random

def split_text(text, min_size=128, max_size=160):
    blocks = []
    while text:
        # Choose a random block size between min_size and max_size
        block_size = random.randint(min_size, max_size)

        # Append the block to the list
        blocks.append(text[:block_size])
        text = text[block_size:]

    return blocks

# The ciphertext text provided
ciphertext = """
Artificial Intelligence (AI) has evolved dramatically since its inception, shifting from a theoretical concept to a powerful force shaping nearly every industry today. The journey began in the mid-20th century when pioneers like Alan Turing and John McCarthy started exploring the idea of creating machines capable of "thinking" like humans. The famous Turing Test, introduced by Alan Turing in 1950, was one of the first theoretical benchmarks for AI. It aimed to determine whether a machine could exhibit intelligent behavior indistinguishable from that of a human. Although AI has yet to fully achieve this ideal in many areas, tremendous progress has been made in developing algorithms that can process information, recognize patterns, and make decisions at levels once thought impossible. From its origins as a niche field within computer science, AI has grown into a multidisciplinary domain involving mathematics, neuroscience, linguistics, and robotics.

One of the major breakthroughs in AI came with the advent of machine learning (ML), a subset of AI that allows computers to "learn" from data without explicit programming. Traditional computer programs follow pre-defined rules to perform specific tasks, but ML algorithms analyze large amounts of data to identify patterns and make predictions. This ability to process and learn from vast datasets has enabled remarkable advancements in areas such as image and speech recognition, natural language processing, and autonomous driving. A particularly significant milestone in machine learning was the development of deep learning, a form of neural networks inspired by the structure of the human brain. Deep learning models, such as convolutional neural networks (CNNs) and recurrent neural networks (RNNs), are capable of handling complex data like images, audio, and text, making them integral to AI-driven technologies like virtual assistants and facial recognition systems. The impact of these innovations can be seen across many sectors, from healthcare and finance to entertainment and transportation.

In healthcare, AI is revolutionizing diagnostics and treatment. Medical professionals now use AI-powered tools to analyze medical images, detect diseases at early stages, and suggest treatment plans based on patient data. For example, algorithms trained on thousands of mammograms can assist radiologists in identifying potential breast cancer cases more accurately and quickly than traditional methods. Furthermore, AI is playing a key role in drug discovery, where it is used to analyze chemical structures and predict how potential drugs will interact with human biology. This dramatically reduces the time and cost involved in bringing new medications to market. In finance, AI is transforming how institutions manage risk, detect fraud, and provide personalized financial services. Algorithms can sift through enormous amounts of transaction data to identify unusual patterns, flagging potentially fraudulent activity before it causes significant harm. Similarly, AI-driven investment platforms analyze market trends and develop strategies for maximizing returns, offering users tailored investment advice based on their financial goals and risk tolerance.

The transportation industry is also being reshaped by AI, particularly in the development of autonomous vehicles. Companies like Tesla, Waymo, and Uber are investing heavily in self-driving car technology, which relies on AI systems to navigate roads, avoid obstacles, and make real-time decisions based on sensor data. These vehicles use a combination of cameras, radar, and lidar to "see" their environment, while AI algorithms interpret the data and control the vehicle's movements. Although fully autonomous cars are not yet mainstream, the progress made in this field is undeniable. When self-driving cars become widely available, they have the potential to reduce traffic accidents, ease congestion, and change the way we think about mobility. Additionally, AI has been instrumental in the development of smart cities, where data collected from sensors and devices is used to optimize energy usage, traffic flow, and public services. By integrating AI with urban planning, cities can become more efficient, sustainable, and responsive to the needs of their residents.

AI's influence extends beyond practical applications into creative fields as well. Artists, musicians, and writers are increasingly using AI tools to generate content, experiment with new ideas, and push the boundaries of their craft. AI-generated music, for example, can analyze existing compositions and create new pieces in the same style, while AI-powered visual art systems like DeepArt allow users to transform photos into images reminiscent of famous painters. In the realm of literature, AI can assist with tasks such as editing and generating written content based on input prompts. Although some critics argue that AI lacks the emotional depth and intuition required for true creativity, others believe that these tools open up exciting possibilities for collaboration between humans and machines. AI is even being used in the film and gaming industries to generate realistic animations and character behaviors, making virtual worlds more immersive and dynamic than ever before.

Despite these advances, AI also raises important ethical questions and challenges. As AI systems become more integrated into everyday life, concerns about privacy, bias, and job displacement have grown. AI algorithms are only as good as the data they are trained on, meaning that biased or incomplete data can lead to unfair outcomes. For instance, facial recognition technology has been shown to be less accurate in identifying people of color, leading to concerns about its use in law enforcement and surveillance. Additionally, the increasing automation of jobs poses a significant challenge for the global workforce. While AI has the potential to create new jobs in fields like data science and robotics, it is also likely to displace workers in industries like manufacturing, retail, and transportation. Policymakers and industry leaders are grappling with how to balance the benefits of AI with the need to protect workers and ensure that the technology is used ethically.

In conclusion, AI has evolved from a theoretical concept into a powerful tool that is transforming industries, improving lives, and reshaping our world. Its applications in healthcare, finance, transportation, and entertainment are already having a profound impact, and the possibilities for future innovations are limitless. However, with great power comes great responsibility. As AI continues to advance, it is crucial to address the ethical challenges it poses, ensuring that its development benefits society as a whole while minimizing potential harm. By fostering collaboration between researchers, businesses, and policymakers, we can create an AI-powered future that is both innovative and inclusive.


"""

# Split the text into blocks
blocks = split_text(ciphertext)
length_of_list = len(blocks)

blocks, length_of_list
# Out:
# (['\nArtificial Intelligence (AI) has evolved dramatically since its inception, shifting from a theoretical concept to a powerful force shaping nearly e',
#   'very industry today. The journey began in the mid-20th century when pioneers like Alan Turing and John McCarthy started exploring the idea of creatin',
#   'g machines capable of "thinking" like humans. The famous Turing Test, introduced by Alan Turing in 1950, was one of the first theoreti',
#   'cal benchmarks for AI. It aimed to determine whether a machine could exhibit intelligent behavior indistinguishable from that of a human. Alt',
#   'hough AI has yet to fully achieve this ideal in many areas, tremendous progress has been made in developing algorithms that can proc',
#   'ess information, recognize patterns, and make decisions at levels once thought impossible. From its origins as a niche field within compu',
# ...

# %%
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.backends import default_backend
import csv

crypto_terms = blocks

def hash_with_cryptography(input_data):
    input_data = input_data.encode('utf-8')
    # Vary the hashing algorithm
    hash_algorithm = random.choice([hashes.SHA1(), hashes.SHA256(), hashes.SHA512()])

    digest = hashes.Hash(hash_algorithm, backend=default_backend())
    digest.update(input_data)
    final = digest.finalize()
    return final, final.hex(), hash_algorithm

def generate_encrypted_dataset(num_texts=len(crypto_terms)):
    dataset = []

    for _ in range(num_texts):
        # Choose a random cryptography term as the original plaintext
        original_text = random.choice(crypto_terms)
        crypto_terms.remove(original_text)

        # Encrypt the text using RSA
        encrypted_data, encrypted_hex, hash_algorithm = hash_with_cryptography(original_text)

        # Append row with original text, encrypted binary, encrypted hex, and padding used
        dataset.append([original_text, len(original_text), encrypted_data, encrypted_hex, hash_algorithm, 'SHA'])

    return dataset

# Generate dataset with crypto-related terms
rsa_dataset = generate_encrypted_dataset()

# Export dataset to CSV
with open('rsaa1_encrypted1234_dataset.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Original Text", "Length", "Encrypted Data (Binary)", "Encrypted Data (Hex)", "Hash_Algorithm", "Algorithm"])
    for row in rsa_dataset:
        writer.writerow(row)
