# %%
import warnings
import pickle

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
warning.filterwarnings("ignore")

# Example data (assuming you have a DataFrame with the extracted features)
df = pd.DataFrame(pd.read_excel('Features_Training_Combined.xlsx'))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 4
#       1 import warnings
#       2 import pickle
# ----> 4 import pandas as pd
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn.ensemble import RandomForestClassifier
#
# ModuleNotFoundError: No module named 'pandas'

# %%
y_train = df['Algorithm']
df.drop(columns=['Original Text', 'Length', 'Encrypted Data (Binary)', 'Encrypted Data (Hex)', 'Algorithm', 'iv', 'length'], inplace=True)
X_train = df
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
y_train
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
X_train
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Example data (assuming you have a DataFrame with the extracted features)
df = pd.DataFrame(pd.read_excel('Features_Testing_Combined.xlsx'))
df.head()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
y_test = df['Algorithm']
df.drop(columns=['Original Text', 'Length', 'Encrypted Data (Binary)', 'Encrypted Data (Hex)', 'Algorithm', 'iv', 'length'], inplace=True)
X_test = df
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
y_test
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
X_test
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
y_train.isnull().sum()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
X_train.isnull().sum()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import numpy as np
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='median')
X_train['block_size'] = imputer.fit_transform(X_train[['block_size']])
X_train.isnull().sum()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X_train['mode'] = label_encoder.fit_transform(X_train[['mode']])
X_train
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
y_test.isnull().sum()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
X_test.isnull().sum()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import numpy as np
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='median')
X_test['block_size'] = imputer.fit_transform(X_test[['block_size']])
X_test.isnull().sum()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X_test['mode'] = label_encoder.fit_transform(X_test[['mode']])
X_test
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)

# Assuming X_train and y_train are your test data
# Convert y_train to a DataFrame for easier manipulation
y_train_correlation_df = pd.DataFrame(y_train_encoded, columns=['Algorithm'])

# Combine X_train and y_train into a single DataFrame
correlation_df = pd.concat([X_train, y_train_correlation_df], axis=1)

# Calculate the correlation matrix
correlation_matrix = correlation_df.corr()
y_predictions_SIH_Testing_Dataset = ['RSA', 'AES', 'RSA', 'RSA', 'ECC', 'AES', 'RSA', 'SHA']

# Extract the correlation of each feature with y_train
correlation_with_algorithm = correlation_matrix['Algorithm'].drop('Algorithm')

# Print the correlation of each feature with y_train
print(correlation_with_algorithm)

# Plot the correlation of each feature with y_train
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_algorithm.index, y=correlation_with_algorithm.values, palette='coolwarm')
plt.xlabel('Features')
plt.ylabel('Correlation with Algorithm')
plt.title('Correlation of Features in X_train with y_train')
plt.xticks(rotation=90)
plt.show()
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
y_train
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Initialize Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

pickle.dump(rf_model, open("model.pkl", "wb"))

# Load the model (optional, just for testing the loading process)
model = pickle.load(open("model.pkl", "rb"))

# Define the path to the backend folder where the model will be saved
model_path = '../backend/model.pkl'

# Save the trained model in the backend folder for use with Flask
with open(model_path, 'wb') as file:
    pickle.dump(rf_model, file)
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
